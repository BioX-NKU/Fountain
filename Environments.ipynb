# %%
# !python --version
# Out:
# Python 3.8.18

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------
# absl-py                       1.4.0
# aiohttp                       3.9.3
# aiosignal                     1.3.1
# alabaster                     0.7.13
# anndata                       0.9.1
# anyio                         3.7.1
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.4.1
# async-timeout                 4.0.3
# attrs                         23.2.0
# Babel                         2.14.0
# backcall                      0.2.0
# bamnostic                     1.1.10
# beautifulsoup4                4.12.3
# bleach                        6.1.0
# Bottleneck                    1.3.7
# Brotli                        1.0.9
# cached-property               1.5.2
# certifi                       2024.2.2
# cffi                          1.16.0
# charset-normalizer            3.3.2
# chex                          0.1.5
# ...
